# %%
from google.colab import drive
drive.mount('/content/drive')

with open('/content/drive/MyDrive/.github_token') as f:
    TOKEN = f.read().strip()

BRANCH_NAME="develop"

# %load_ext autoreload
# %autoreload 2

# !git clone -b {BRANCH_NAME} https://{TOKEN}@github.com/Rapirys/ProjectPIG.git
# %cd ProjectPIG
# %pip install swig
# %pip install -r requirements.txt

# %%
# %run -i NaturalDreamer/main.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from NaturalDreamer.main import main
#       3 main()
#
# File ~/PycharmProjects/ProjectPIG/NaturalDreamer/main.py:5
#       3 import argparse
#       4 import os
# ----> 5 from dreamer    import Dreamer
#       6 from utils      import loadConfig, seedEverything, plotMetrics
#       7 from envs       import getEnvProperties, GymPixelsProcessingWrapper, CleanGymWrapper
#
# ModuleNotFoundError: No module named 'dreamer'
